# %%
import pandas as pd
dat_mtcars = pd.read_csv('mtcars.csv',index_col=0)
dat_mtcars
#dat_mtcars.head()
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
dat_mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
dat_mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
dat_mtcars.shape
# Out:
# (32, 11)

# %%
dat_mtcars["mpg"].plot(kind = "hist" , bins=10,title="Histogram of th Distribution of MPG")
# Out:
# <Axes: title={'center': 'Histogram of th Distribution of MPG'}, ylabel='Frequency'>

# %%
#1
dat_mtcars["mpg"].plot(kind='box')
# Out:
# <Axes: >

# %%
#2
max_mpg=dat_mtcars["mpg"].max()
dat_mtcars[dat_mtcars["mpg"]==max_mpg]
# Out:
#                  mpg  cyl  disp  hp  drat     wt  qsec  vs  am  gear  carb
# model
# Toyota Corolla  33.9    4  71.1  65  4.22  1.835  19.9   1   1     4     1

# %%
#3
dat_mtcars['am'].nunique()
# Out:
# 2

# %%
dat_mtcars["am"].value_counts()
# Out:
# am
# 0    19
# 1    13
# Name: count, dtype: int64

# %%
#4
minhp=dat_mtcars["hp"].min()
dat_mtcars[dat_mtcars['hp']==minhp]
# Out:
#               mpg  cyl  disp  hp  drat     wt   qsec  vs  am  gear  carb
# model
# Honda Civic  30.4    4  75.7  52  4.93  1.615  18.52   1   1     4     2

# %%
#5
dat_mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
dat_mtcars["disp"].plot(kind='box')
# Out:
# <Axes: >

# %%
#6
heaviest=dat_mtcars['wt'].max()
dat_mtcars[dat_mtcars['wt']==heaviest]['gear']
# Out:
# model
# Lincoln Continental    3
# Name: gear, dtype: int64

# %%
#7
maximum=dat_mtcars['qsec'].max()
dat_mtcars[dat_mtcars['qsec']==maximum]
# Out:
#            mpg  cyl   disp  hp  drat    wt  qsec  vs  am  gear  carb
# model
# Merc 230  22.8    4  140.8  95  3.92  3.15  22.9   1   0     4     2

# %%
#8
dat_man= dat_mtcars[dat_mtcars["am"]==1]["mpg"] 
print("Average MPG of manual cars:",dat_man.mean())
dat_auto= dat_mtcars[dat_mtcars["am"]==0]["mpg"]
print(f"Average MPG of automatic cars:{dat_auto.mean()}")
# Out:
# Average MPG of manual cars: 24.39230769230769
# Average MPG of automatic cars:17.147368421052633

# %%
#9
import pandas as pd

# Load the dataset
mtcars = pd.read_csv('mtcars.csv')


mtcars['am'] = mtcars['am'].map({0: 'Automatic', 1: 'Manual'})


mtcars[['mpg', 'am']].boxplot(by='am')
# Out:
# <Axes: title={'center': 'mpg'}, xlabel='[am]'>

# %%
#10
dat_x= dat_mtcars[["mpg","wt"]]
dat_x=dat_x.reset_index(drop=True)   #drop the old index?
dat_x.plot(kind='scatter', x='mpg', y='wt', color='red', title='Scatter Plot from DataFrame')
# Out:
# <Axes: title={'center': 'Scatter Plot from DataFrame'}, xlabel='mpg', ylabel='wt'>

# %%
#11
dat=dat_mtcars['gear'].value_counts()
#dat_mtcars[dat_mtcars['gear']==3].count()['gear']
dat
# Out:
# gear
# 3    15
# 4    12
# 5     5
# Name: count, dtype: int64

# %%
#12
dat_x= dat_mtcars[["mpg","gear"]]
dat_x= dat_x.reset_index(drop=True)
dat_x.plot(kind='scatter', x='mpg', y='gear', color='blue', title='Scatter Plot from DataFrame')
# Out:
# <Axes: title={'center': 'Scatter Plot from DataFrame'}, xlabel='mpg', ylabel='gear'>

# %%
#13
dat_x= dat_mtcars[["hp","cyl"]]
dat_x= dat_x.reset_index(drop=True)
dat_x.plot(kind='scatter', x='hp', y='cyl', color='blue', title='Scatter Plot from DataFrame')
# Out:
# <Axes: title={'center': 'Scatter Plot from DataFrame'}, xlabel='hp', ylabel='cyl'>

# %%
#14
dat_x= dat_mtcars[["disp","hp"]]
dat_x= dat_x.reset_index(drop=True)
dat_x.plot(kind='bar', x='disp', y='hp', color='red', title='Scatter Plot from DataFrame')
# Out:
# <Axes: title={'center': 'Scatter Plot from DataFrame'}, xlabel='disp'>

# %%
#15
mtcars[['mpg' , 'hp']].plot(kind='bar')
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_excel('cereals.xls')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 1                    All-Bran   K    C        70        4    1     260    9.0
# 2   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 3              Almond_Delight   R    C       110        2    2     200    1.0
# 4     Apple_Cinnamon_Cheerios   G    C       110        2    2     180    1.5
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71                    Triples   G    C       110        2    1     250    0.0
# 72                       Trix   G    C       110        1    1     140    0.0
# 73                 Wheat_Chex   R    C       100        3    1     230    3.0
# 74                   Wheaties   G    C       100        3    1     200    3.0
# 75        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#1
df['name'].count()
# Out:
# np.int64(76)

# %%
#2
df['mfr'].value_counts()
# Out:
# mfr
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     5
# A     1
# Name: count, dtype: int64

# %%
#3
df['type'].value_counts()
# Out:
# type
# C    73
# H     3
# Name: count, dtype: int64

# %%
#4
mincereal=df.loc[df['rating'].idxmax()]['name']
maxcereal=df.loc[df['rating'].idxmin()]['name']
mincereal,maxcereal
# Out:
# ('All-Bran_with_Extra_Fiber', "Cap'n'Crunch")

# %%
#5
cereals.plot(kind="scatter",x="type",y="rating",title="Scatter Plot")
# Out:
# <Axes: title={'center': 'Scatter Plot'}, xlabel='type', ylabel='rating'>

# %%
#6
highest_fiber = cereals[cereals['fiber'] == cereals['fiber'].max()]['name']
lowest_sugar = cereals[cereals['sugars'] == cereals['sugars'].min()]['name']
highest_fiber , lowest_sugar
# Out:
# (2    All-Bran_with_Extra_Fiber
#  Name: name, dtype: object,
#  56    Quaker_Oatmeal
#  Name: name, dtype: object)

# %%
#7
cereals[cereals['protein'] > 3]
# Out:
#                                      name mfr type  calories  protein  fat  \
# 1                                All-Bran   K    C        70        4    1
# 2               All-Bran_with_Extra_Fiber   K    C        50        4    0
# 10                               Cheerios   G    C       110        6    2
# 40                                   Life   Q    C       100        4    2
# 42                                  Maypo   A    H       100        4    1
# 43   Muesli_Raisins,_Dates,_&amp;_Almonds   R    C       150        4    3
# 44  Muesli_Raisins,_Peaches,_&amp;_Pecans   R    C       150        4    3
# 55                     Quaker_Oat_Squares   Q    C       100        4    1
# 56                         Quaker_Oatmeal   Q    H       100        5    2
# 66                              Special_K   K    C       110        6    0
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# ...

# %%
#8
Shelf_col = 'Display Display Shelf' if 'Display Shelf' in cereals.columns else 'Display Shelf'

display_Display_Shelf_counts = cereals["shelf"].value_counts()
print("Cereal Count by Display Shelf:\n", 
display_Display_Shelf_counts)
# Out:
# Cereal Count by Display Shelf:
#  shelf
# 3    35
# 2    21
# 1    20
# Name: count, dtype: int64

# %%
#9
cereals[['mfr', "sugars"]].groupby('mfr').mean()
# Out:
#        sugars
# mfr
# A    3.000000
# G    7.954545
# K    7.565217
# N    1.000000
# P    8.777778
# Q    5.250000
# R    6.125000

# %%
#10
cereals[['mfr', "calories"]].groupby('mfr').mean()
# Out:
#        calories
# mfr
# A    100.000000
# G    111.363636
# K    108.695652
# N     90.000000
# P    108.888889
# Q     95.000000
# R    115.000000

# %%
#11
nutritional_cols = [col for col in ['calories', 'sugars', 'protein', 
'dietary Fiber'] if col in cereals.columns]
avg_nutrition = cereals[nutritional_cols].mean()
print("Average Nutritional Content:\n", avg_nutrition)
# Out:
# Average Nutritional Content:
#  calories    107.368421
# sugars        6.934211
# protein       2.526316
# dtype: float64

# %%
#12
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot(x='sugars', y='calories', data=df)
plt.grid(True)
plt.show()

# %%
#13
#cereals['Rating'] = pd.qcut(cereals["rating"], q=2, labels=['Low', 'High'])
#cereals[['rating', "sugars"]].groupby('rating').mean()
data=df.groupby(['rating'])['sugars'].sum()
data
# Out:
# rating
# 18.042851    12
# 19.823573     9
# 21.871292    11
# 22.396513    13
# 22.736446    13
#              ..
# 64.533816     0
# 68.235885     0
# 72.801787     0
# 74.472949     0
# 93.704912     0
# Name: sugars, Length: 76, dtype: int64

# %%
#14
healthy_cereals = cereals[(cereals["fiber"] > 3) & (cereals["sugars"] < 5)]
healthy_cereals[['name', "rating"]]
# Out:
#                          name     rating
# 2   All-Bran_with_Extra_Fiber  93.704912
# 63     Shredded_Wheat_'n'Bran  74.472949

# %%
#15
sns.lineplot(x='rating', y='shelf', data=df)
plt.show()
