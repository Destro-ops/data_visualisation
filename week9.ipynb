# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sentiment.csv")
df
# Out:
#       ID                                               Text    Sentiment  \
# 0      0   Enjoying a beautiful day at the park!        ...   Positive
# 1      1   Traffic was terrible this morning.           ...   Negative
# 2      2   Just finished an amazing workout! 💪          ...   Positive
# 3      3   Excited about the upcoming weekend getaway!  ...   Positive
# 4      4   Trying out a new recipe for dinner tonight.  ...   Neutral
# ..   ...                                                ...          ...
# 727  728  Collaborating on a science project that receiv...       Happy
# 728  729  Attending a surprise birthday party organized ...       Happy
# 729  730  Successfully fundraising for a school charity ...       Happy
# 730  731  Participating in a multicultural festival, cel...       Happy
# 731  732  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# ...

# %%
#1
df['Sentiment'] = df['Sentiment'].str.strip().str.lower()
df['Text'] = df['Text'].str.strip().str.lower()
df
# Out:
#       ID                                               Text Sentiment  \
# 0      0              enjoying a beautiful day at the park!  positive
# 1      1                 traffic was terrible this morning.  negative
# 2      2                just finished an amazing workout! 💪  positive
# 3      3        excited about the upcoming weekend getaway!  positive
# 4      4        trying out a new recipe for dinner tonight.   neutral
# ..   ...                                                ...       ...
# 727  728  collaborating on a science project that receiv...     happy
# 728  729  attending a surprise birthday party organized ...     happy
# 729  730  successfully fundraising for a school charity ...     happy
# 730  731  participating in a multicultural festival, cel...     happy
# 731  732  organizing a virtual talent show during challe...     happy
#
#             Timestamp                                   User     Platform  \
# ...

# %%
#2


sentiment_counts = df['Sentiment'].value_counts().head(10)
print(sentiment_counts)


plt.figure(figsize=(14, 14))
sentiment_counts.plot.pie(autopct='%1.1f%%')
plt.title('Sentiment Distribution')
plt.ylabel('')
plt.show()
# Out:
# Sentiment
# positive       45
# joy            44
# excitement     37
# contentment    19
# neutral        18
# gratitude      18
# curiosity      16
# serenity       15
# happy          14
# despair        11
# Name: count, dtype: int64

# %%
#3

text_length = df['Text'].str.len()
text_length_df = text_length.reset_index()
text_length_df.columns = ['Index', 'Text Length']
text_length_df



plt.figure(figsize=(10, 6))
sns.histplot(data=text_length_df, x='Text Length', bins=20, kde=True, color="blue")
plt.title("Distribution of Text Lengths")
plt.xlabel("Text Length")
plt.ylabel("Frequency")
plt.show()

# %%
text_length = df['Text'].str.len()
text_length_df = text_length.reset_index()
text_length_df.columns=['index', 'text length']
text_length_df
# Out:
#      index  text length
# 0        0           37
# 1        1           34
# 2        2           35
# 3        3           43
# 4        4           43
# ..     ...          ...
# 727    727          109
# 728    728          105
# 729    729           98
# 730    730          103
# 731    731           96
#
# [732 rows x 2 columns]

# %%
#4
df[df['Likes']==df['Likes'].max()]
# Out:
#       ID                                               Text         Sentiment  \
# 335  336  thrilled to witness the grandeur of a cultural...    Thrill
# 345  346  motivated to achieve fitness goals after an in...    Motivation
# 355  356  anticipation for an upcoming adventure in an e...    Anticipation
# 368  369  elation over discovering a rare book in a quai...    Elation
# 382  383  a sense of wonder at the vastness of the cosmo...       Wonder
# 402  403  awe-inspired by the vastness of the cosmos on ...     Wonder
# 432  433  heartache deepens, a solitary journey through ...        Despair
# 470  471  dancing on sunshine, each step a celebration o...              Joy
# 481  482  surrounded by the colors of joy, a canvas pain...              Joy
# 510  511  at the front row of adele's concert, each note...          Emotion
# 520  521  at a justin bieber concert, the infectious bea...       Enthusiasm
# ...

# %%
#5
df[df['Retweets']==df['Retweets'].max()]
# Out:
#       ID                                               Text         Sentiment  \
# 335  336  thrilled to witness the grandeur of a cultural...    Thrill
# 345  346  motivated to achieve fitness goals after an in...    Motivation
# 355  356  anticipation for an upcoming adventure in an e...    Anticipation
# 368  369  elation over discovering a rare book in a quai...    Elation
# 382  383  a sense of wonder at the vastness of the cosmo...       Wonder
# 402  403  awe-inspired by the vastness of the cosmos on ...     Wonder
# 432  433  heartache deepens, a solitary journey through ...        Despair
# 470  471  dancing on sunshine, each step a celebration o...              Joy
# 481  482  surrounded by the colors of joy, a canvas pain...              Joy
# 510  511  at the front row of adele's concert, each note...          Emotion
# 520  521  at a justin bieber concert, the infectious bea...       Enthusiasm
# ...

# %%
#6
df['Country'] = df['Country'].str.strip().str.title()

positive_sentiment_df = df[df['Sentiment'] == 'positive']
top_countries_positive = positive_sentiment_df['Country'].value_counts().head(5)
print(top_countries_positive)

plt.figure
sns.barplot(x=top_countries_positive.index, y=top_countries_positive.values, palette='crest')
plt.title('Top 5 Countries with Positive Sentiment')
plt.xlabel('Country')
plt.ylabel('Number of Posts')
plt.show()
# Out:
# Country
# Usa          18
# Uk           10
# Canada        8
# India         7
# Australia     2
# Name: count, dtype: int64
# C:\Users\Adarsh Yerneni\AppData\Local\Temp\ipykernel_6480\471224015.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_countries_positive.index, y=top_countries_positive.values, palette='crest')

# %%
#7
travel_texts = df[df['Hashtags'].str.contains('travel', case=False)]
travel_texts[['Text', 'Hashtags']]
# Out:
#                                                   Text  \
# 3          excited about the upcoming weekend getaway!
# 72   excitement building up for the upcoming vacation!
# 84   enjoying every moment of this trip—pure enjoym...
# 145  arousal of excitement before a much-awaited trip.
# 596  spontaneously booked a weekend getaway. advent...
# 610  embarked on a road trip to revisit cherished p...
# 622  embarked on a solo travel adventure, discoveri...
#
#                                             Hashtags
# 3          #Travel #Adventure
# 72       #Excitement #TravelPlans
# 84     #Enjoyment #Travel
# 145   #Arousal #TravelAdventure
# 596                       #GetawayGoals #TeenTravel
# 610                  #CherishedPlaces #SeniorTravel
# 622                #DiscoverNewPlaces #SeniorTravel

# %%
#8
df_2020 = df[df['Year'] == 2020]
df_2020_negative = df_2020[df_2020['Sentiment'] == 'negative']
df_2020_negative
# Out:
#       ID                                               Text Sentiment  \
# 122  123  elation after a surprise reunion with old frie...  negative
# 134  135  reverence for the artistry displayed in a museum.  negative
# 146  147  enthusiasm for a new artistic project in the w...  negative
# 161  162  reverence for the wonders of nature on a hikin...  negative
# 166  167  jealousy consumes me as i witness others' succ...  negative
# ..   ...                                                ...       ...
# 552  553  facing a defeat in the championship, the boxer...  negative
# 564  565  in the world of science, a breakthrough discov...  negative
# 574  575  surrounded by the vibrant colors of a flower g...  negative
# 730  731  participating in a multicultural festival, cel...  negative
# 731  732  organizing a virtual talent show during challe...  negative
#
#             Timestamp                                  User     Platform  \
# ...

# %%
#9
happiness_posts = df[df['Sentiment'] == 'happiness']
happiness_posts[['User', 'Text', 'Sentiment']]
# Out:
#                      User                                               Text  \
# 56       ProudFriend       pure happiness: celebrating a loved one's achi...
# 80       NewParentJoy      overflowing happiness: welcoming a new family ...
# 367   SunnyDayEnthusiast   happiness blooms like flowers in a garden on a...
# 471       EchoedLaughter   laughter echoes in the air, a chorus of happin...
# 488     LaughterSymphony   a symphony of laughter, each note a key to unl...
#
#      Sentiment
# 56   happiness
# 80   happiness
# 367  happiness
# 471  happiness
# 488  happiness

# %%
#10
df_filtered = df[df['Sentiment'].isin(['positive', 'negative', 'neutral'])]
year_country_sentiment = df_filtered.groupby(['Year', 'Country', 'Sentiment']).size().unstack(fill_value=0)
print(year_country_sentiment)

plt.figure(figsize=(14, 8))
sns.heatmap(year_country_sentiment.T, annot=True, fmt='d', cmap='coolwarm', linewidths=0.5)
plt.title('Sentiment Distribution by Year and Country')
plt.xlabel('Year & Country')
plt.ylabel('Sentiment')
plt.show()
# Out:
# Sentiment       negative
# Year Country
# 2010 Australia         1
#      Canada            1
#      India             1
# 2011 Canada            2
#      India             1
# ...                  ...
# 2023 India            25
#      Japan             3
#      Jordan            1
#      Uk               73
#      Usa             101
#
# [122 rows x 1 columns]
